# %%
from IPython.display import display
from PIL import Image
from yolo import YOLO

def objectDetection(yolo,file, model_path, class_path, imgname):
#     yolo = YOLO(model_path=model_path, classes_path=class_path, anchors_path="model_data/yolo_anchors.txt", image_name=imgname)
    image = Image.open(file)
    result_image = yolo.detect_image(image,imgname)
#     display(result_image)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import random

yolo = YOLO(model_path='logs/002/trained_weights_transfer_1.h5', classes_path='model_data/yolo_classes.txt', anchors_path="model_data/yolo_anchors.txt")

with open("/home/shjeong/Data/HumanHeadDetection/HollywoodHeads/Splits/test.txt", 'r') as f:
    lines = f.readlines()

for i in range(0,len(lines)):
    image_filepath = "/home/shjeong/Data/HumanHeadDetection/HollywoodHeads/JPEGImages/"
    image_filename = image_filepath + lines[i][:-1] + ".jpeg"
    objectDetection(yolo,image_filename, 'logs/002/trained_weights_transfer_1.h5', 'model_data/yolo_classes.txt',lines[i][:-1])
# Out:
# length of classes:  1
# logs/002/trained_weights_transfer_1.h5 model, anchors, and classes loaded.
# (416, 416, 3)
# Found 0 boxes for img
# inference time  1.1441590562462807
# (416, 416, 3)
# Found 0 boxes for img
# inference time  0.3122077211737633
# (416, 416, 3)
# Found 1 boxes for img
# head 0.35 (361, 25) (513, 312)
# inference time  0.3119511492550373
# (416, 416, 3)
# Found 0 boxes for img
# inference time  0.3079567514359951
# (416, 416, 3)
# Found 0 boxes for img
# inference time  0.3098983205854893
# (416, 416, 3)
# Found 1 boxes for img
# head 0.47 (317, 0) (470, 275)
# inference time  0.30737005174160004
# (416, 416, 3)
# Found 1 boxes for img
# head 0.51 (280, 0) (441, 277)
# inference time  0.297691710293293
# (416, 416, 3)
# Found 1 boxes for img
# head 0.42 (279, 46) (504, 300)
# inference time  0.3080851249396801
# (416, 416, 3)
# Found 0 boxes for img
# inference time  0.30096554197371006
# (416, 416, 3)
# Found 0 boxes for img
# ...
